# %% [markdown]
# # So, is the climate changing?
#
# First things first – make sure to load the climate `DataFrame` you
# stored in the previous notebooks using Jupyter cell magic:

# %%
# Load all stored variables
# %store -r
bco_ann_climate_df
# Out:
#             Precip_In     Temp_F     C_temp     TOBS_C
# DATE
# 1893-01-01   0.025543        NaN        NaN        NaN
# 1894-01-01   0.058841        NaN        NaN        NaN
# 1895-01-01   0.117090        NaN        NaN        NaN
# 1896-01-01        NaN        NaN        NaN        NaN
# 1897-01-01   0.068922        NaN        NaN        NaN
# ...               ...        ...        ...        ...
# 2019-01-01   0.057644  54.426997  12.459443  12.459443
# 2020-01-01   0.046721  57.691460  14.273033  14.273033
# 2021-01-01   0.056658  57.538462  14.188034  14.188034
# 2022-01-01   0.051479  56.139726  13.410959  13.410959
# 2023-01-01   0.076740  58.996337  14.997965  14.997965
#
# [131 rows x 4 columns]

# %% [markdown]
# ## Quantify how fast the climate is changing with a trend line
#
# Global climate change causes different effects in different places when
# we zoom in to a local area. However, you probably noticed when you
# looked at mean annual temperatures over time that they were rising. We
# can use a technique called **Linear Ordinary Least Squares (OLS)
# Regression** to determine how quickly temperatures are rising on
# average.
#
# Before we get started, it’s important to consider that OLS regression is
# not always the right technique, because it makes some important
# assumptions about our data:
#
# ### Random error
# Variation in temperature can be caused by many things beyond global
# climate change. For example, temperatures often vary with patterns of
# ocean surface temperatures (*teleconnections*), the most famous of which
# are El Niño and La Niña. By using a linear OLS regression, we’re
# assuming that all the variation in temperature except for climate change
# is random.
#
# ### Normally distributed error
# If you have taken a statistics class, you probably learned a lot about
# the normal, or Gaussian distribution. For right now, what you need to
# know is that OLS regression is useful for identifying trends in average
# temperature, but wouldn’t be appropriate for looking at trends in daily
# precipitation (because most days have zero precipitation), or at maximum
# or minimum annual temperatures (because these are extreme values, and
# the normal distribution tends to underestimate the likelihood of large
# events).
#
# ### Linearity
# We’re assuming that temperatures are increasing or decreasing at a
# constant rate over time. We wouldn’t be able to look at rates that
# change over time. For example, many locations in the Arctic remained the
# same temperature for much longer than the rest of the world, because ice
# melt was absorbing all the extra heat. Linear OLS regression wouldn’t be
# able to identify when the temperature rise began on its own.
#
# ### Stationarity
#
# We’re assuming that variation in temperature caused by things *other*
# than global climate change (e.g. the random error) behaves the same over
# time. For example, the linear OLS regression can’t take increased
# variability from year to year into account, which is a common effect of
# climate change. We often see “global weirding”, or more extreme head
# *and* cold, in addition to overall increases. You can observe this most
# easily by looking at your daily data again. Does it seem to be fanning
# in or out over time?
#
#
#
# ## YOUR TASK: Is linear OLS regression right for your data?
#
# It’s pretty rare to encounter a perfect statistical model where all the
# assumptions are met, but you want to be on the lookout for serious
# discrepancies, especially when making predictions. For example,
# [ignoring assumptions about Gaussian error arguably led to the 2008
# financial crash](https://www.wired.com/2009/02/wp-quant/).
#
# 1. Take a look at your data. In the cell below, write a few
#     sentences about ways your data does and does not meet the linear OLS
#     regression assumptions.

# %% [markdown]
# While there are significant variances, in part caused by missing data, there is a slight trend toward an increase in average annual temperature between 1903 and 2023.
#
# query
# given the dataframe bco_ann_climate_df where DATE contains the first day of january for the given year as the index and TOBS_C contains the average mean temperature in Celsius , how would I fit an ordinary least squares linear models to temperature over time?
#
# Share
#
#
# You said:
#  given the dataframe bco_ann_climate_df where DATE contains the first day of january for the given year as the index and TOBS_C contains the average mean temperature in Celsius , how would I fit an ordinary least squares linear models to temperature over time?
#
# 2/2
#
# ChatGPT said:
# ChatGPT
# To fit an Ordinary Least Squares (OLS) linear model to the temperature over time using the DataFrame bco_ann_climate_df, where DATE is the index and TOBS_C contains the average mean temperature in Celsius, you can use the statsmodels library in Python. Here's a step-by-step guide:
#
# Ensure the Date Column is in the Correct Format: Ensure that the DATE index is in datetime format. If it's not, convert it using pd.to_datetime().
#
# Extract the Year from the Date Index: Since DATE is in the format of the first day of January, you can extract the year for use in the regression.
#
# Fit the OLS Model: Use the statsmodels library to fit an OLS regression model where the year is the independent variable and TOBS_C is the dependent variable.
#
# Explanation:
# sm.add_constant(X): Adds an intercept (constant) to the regression model.
# sm.OLS(y, X).fit(): Fits an OLS regression model with Year as the predictor of TOBS_C.
# model.summary(): Provides detailed statistics of the fitted model, including coefficients, R-squared values, and significance levels.
# This approach will allow you to understand the relationship between temperature (TOBS_C) and time (Year).

# %% [markdown]
# > **Your task:**
# >
# > The following cell contains package imports that you will need to
# > calculate and plot an OLS Linear trend line. Make sure to run the cell
# > before moving on, and if you have any additional packages you would
# > like to use, add them here later on.

# %%
# Advanced options on matplotlib/seaborn/pandas plots
import matplotlib.pyplot as plt
# Common statistical plots for tabular data
import seaborn as sns
# Fit an OLS linear regression
from sklearn.linear_model import LinearRegression

# %% [markdown]
# > **Your task: Regression**
# >
# > 1.  To get sample code, ask ChatGPT how to fit a linear model to your
# >     data. If you’re new to using large language modesl, go ahead and
# >     check out [our
# >     query](https://chatgpt.com/share/649b897b-9075-457e-8e12-308f795312a1)
# > 2.  Copy code that uses the `scikit-learn` package to perform a OLS
# >     linear regression to the code cell below.
# > 3.  Check out your previous plot. Does it make sense to include all
# >     the data when calculating a trend line? Be sure to select out data
# >     that meets the OLS assumptions.
#
# > **Note**
# >
# > We know that some computers, networks, and countries block LLM (large
# > language model) sites, and that LLMs can sometimes perpetuate
# > oppressive or offensive language and ideas. However, LLMs are
# > increasingly standard tools for programming – [according to
# > GitHub](https://github.com/features/copilot) many developers code 55%
# > faster with LLM assistance. We also see in our classes that LLMs give
# > students the ability to work on complex real-world problems earlier
# > on. We feel it’s worth the trade-off, and at this point we would be
# > doing you a disservice professionally to teach you to code without
# > LLMs. If you can’t access them, don’t worry – we’ll present a variety
# > of options for finding example code. For example, you can also search
# > for an example on a site like
# > [StackOverflow](https://stackoverflow.com/) (this is how we all
# > learned to code, and with the right question it’s a fantastic resource
# > for any coder to get access to up-to-date information from world
# > experts quickly). You can also use our solutions as a starting point.

# %%
import pandas as pd
import statsmodels.api as sm

# Ensure DATE is datetime type (if not already)
bco_ann_climate_df.index = pd.to_datetime(bco_ann_climate_df.index)

# Extract the year from the DATE index
bco_ann_climate_df['Year'] = bco_ann_climate_df.index.year

# Define the independent variable (Year) and dependent variable (TOBS_C)
X = bco_ann_climate_df['Year']
y = bco_ann_climate_df['TOBS_C']

# Add a constant to the independent variable (intercept term)
X = sm.add_constant(X)

# Fit the OLS model
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 TOBS_C   R-squared:                         nan
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Tue, 24 Sep 2024   Prob (F-statistic):                nan
# Time:                        20:14:18   Log-Likelihood:                    nan
# No. Observations:                 131   AIC:                               nan
# Df Residuals:                     129   BIC:                               nan
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const             nan        nan        nan        nan         nan         nan
# ...

# %% [markdown]
# ## Plot your trend line
#
# Trend lines are often used to help your audience understand and process
# a time-series plot. In this case, we’ve chosed mean temperature values
# rather than extremes, so we think OLS is an appropriate model to use to
# show a trend.
#
# > **Is it ok to plot a trend line even if OLS isn’t an appropriate
# > model?**
# >
# > This is a tricky issue. When it comes to a trend line, choosing a
# > model that is technically more appropriate may require much more
# > complex code without resulting in a noticeably different trend line.
# >
# > We think an OLS trend line is an ok visual tool to indicate the
# > approximate direction and size of a trend. If you are showing standard
# > error, making predictions or inferences based on your model, or
# > calculating probabilities (p-values) based on your model, or making
# > statements about the statistical significance of a trend, we’d suggest
# > reconsidering your choice of model.
#
# #  Your task: Regression
#
# 1.  Add values for x (year) and y (temperature) to plot a regression
#     plot. You will have to select out the year from the index values,
#     just like you probably did when fitting your linear model above!
# 2.  Label the axes of your plot with the `title`, `xlabel`, and `ylabel`
#     parameters of `ax.set()`. This function takes your plot and changes the settings. You can see how to add the degree symbol in the example
#     below. Make sure your labels match what you’re plotting! :::

# %%
# Plot annual average temperature data with a trend line
ax = sns.regplot(
    x=bco_ann_climate_df['Year'], 
    y=bco_ann_climate_df['TOBS_C'],
    )
# Set plot labels
ax.set(
    title='Boulder Colorado Observed Temperature Trend',
    xlabel='YEAR',
    ylabel='Temperature ($^\circ$F)'
)
# Display the plot without extra text
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Plot annual average temperature data with a red trend line
ax = sns.regplot(
    x=bco_ann_climate_df['Year'], 
    y=bco_ann_climate_df['TOBS_C'],
    line_kws={'color': 'red'},  # Change the trend line to red
)

# Set plot labels
ax.set(
    title='Boulder Colorado Observed Temperature Trend',
    xlabel='YEAR',
    ylabel='Temperature ($^\circ$C)'  # Updated unit to Celsius
)

# Fit the OLS model to get the slope
X = sm.add_constant(bco_ann_climate_df['Year'])  # Add constant for the intercept
model = sm.OLS(bco_ann_climate_df['TOBS_C'], X).fit()  # Fit the model

# Extract the slope (coefficient of the 'Year')
slope = model.params['Year']
print(f"Slope of the trend line: {slope:.4f} °C/year")

#change to stuff in video by Elsa
# slope = model.coef_[0],
# intercept = model.intercept_,

# printf(f"Slope: {slope}"),
# printf(f"Intercept: {intercept}"),

# Display the plot without extra text
plt.show()
# Out:
# Slope of the trend line: nan °C/year

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd

# Assuming bco_ann_climate_df is defined and loaded correctly with 'Year' and 'TOBS_C' columns
# Filter the data between 1920 and 2020
bco_ann_climate_df_filtered = bco_ann_climate_df[
    (bco_ann_climate_df['Year'] >= 1920) & (bco_ann_climate_df['Year'] <= 2020)
]

# Remove rows with missing or infinite values to avoid NaN slope
bco_ann_climate_df_filtered = bco_ann_climate_df_filtered.replace([np.inf, -np.inf], np.nan).dropna()

# Plot annual average temperature data with a red trend line for the filtered data
ax = sns.regplot(
    x=bco_ann_climate_df_filtered['Year'],
    y=bco_ann_climate_df_filtered['TOBS_C'],
    line_kws={'color': 'red'},  # Change the trend line to red
)

# Set plot labels
ax.set(
    title='Boulder Colorado Observed Temperature Trend (1920-2020)',
    xlabel='YEAR',
    ylabel='Temperature ($^\circ$C)'  # Updated unit to Celsius
)

# Prepare data for scikit-learn Linear Regression
X = bco_ann_climate_df_filtered[['Year']].values  # 2D array for scikit-learn
y = bco_ann_climate_df_filtered['TOBS_C'].values

# Fit the Linear Regression model
model = LinearRegression()
model.fit(X, y)

# Extract the slope and intercept
slope = model.coef_[0]
intercept = model.intercept_
print(f"Slope: {slope:.4f} °C/year")
print(f"Intercept: {intercept:.4f} °C")

# Annotate the predicted values on the plot for 1920 and 2020
years = np.array([1920, 2020]).reshape(-1, 1)
predicted_temps = model.predict(years)

for year, temp in zip(years.flatten(), predicted_temps):
    ax.text(year, temp, f'{temp:.2f}', color='red', fontsize=10, ha='center', va='bottom')

# Display the plot without extra text
plt.grid(which='both', linestyle=':', linewidth=0.5)
plt.show()
# Out:
# Slope: 0.0151 °C/year
# Intercept: -17.0780 °C

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Filter the data between 1920 and 2020
# bco_ann_climate_df_filtered = bco_ann_climate_df[(bco_ann_climate_df['Year'] >= 1920) & (bco_ann_climate_df['Year'] <= 2020)]


# Plot annual average temperature data with a red trend line for the filtered data
ax = sns.regplot(
    x=bco_ann_climate_df_filtered['Year'], 
    y=bco_ann_climate_df_filtered['TOBS_C'],
    line_kws={'color': 'red'},  # Change the trend line to red
)

# Set plot labels
ax.set(
    title='Boulder Colorado Observed Temperature Trend (1920-2020)',
    xlabel='YEAR',
    ylabel='Temperature ($^\circ$C)'  # Updated unit to Celsius
)

# Fit the OLS model to get the slope for the filtered data
X = sm.add_constant(bco_ann_climate_df_filtered['Year'])  # Add constant for the intercept
model = sm.OLS(bco_ann_climate_df_filtered['TOBS_C'], X).fit()  # Fit the model

# Extract the slope (coefficient of the 'Year')
slope = model.params['Year']
print(f"Slope of the trend line (1920-2020): {slope:.4f} °C/year")

# Display the plot without extra text
plt.show()
bco_ann_climate_df_filtered
# Out:
# Slope of the trend line (1920-2020): 0.0151 °C/year
#             Precip_In     Temp_F     C_temp     TOBS_C  Year
# DATE
# 1920-01-01   0.064083  52.578652  11.432584  11.432584  1920
# 1921-01-01   0.139318  55.683196  13.157331  13.157331  1921
# 1922-01-01   0.067980  54.320442  12.400246  12.400246  1922
# 1923-01-01   0.086013  50.923288  10.512938  10.512938  1923
# 1924-01-01   0.035738  54.765027  12.647237  12.647237  1924
# ...               ...        ...        ...        ...   ...
# 2016-01-01   0.047131  57.836066  14.353370  14.353370  2016
# 2017-01-01   0.061617  60.129129  15.627294  15.627294  2017
# 2018-01-01   0.052740  57.005479  13.891933  13.891933  2018
# 2019-01-01   0.057644  54.426997  12.459443  12.459443  2019
# 2020-01-01   0.046721  57.691460  14.273033  14.273033  2020
#
# [98 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Plot annual average temperature data with a red trend line
ax = sns.regplot(
    x=bco_ann_climate_df['Year'], 
    y=bco_ann_climate_df['TOBS_C'],
    line_kws={'color': 'red'},  # Change the trend line to red
)

# Set plot labels
ax.set(
    title='Boulder Colorado Observed Temperature Trend',
    xlabel='YEAR',
    ylabel='Temperature ($^\circ$C)'  # Updated unit to Celsius
)

# Fit the OLS model to get the slope
X = sm.add_constant(bco_ann_climate_df['Year'])  # Add constant for the intercept
model = sm.OLS(bco_ann_climate_df['TOBS_C'], X).fit()  # Fit the model

# Extract the slope (coefficient of the 'Year') and intercept
slope = model.params['Year']
intercept = model.params['const']
print(f"Slope of the trend line: {slope:.4f} °C/year")

# Predict temperature values at 1920 and 2020
temp_1920 = intercept + slope * 1920
temp_2020 = intercept + slope * 2020

# Label the 1920 and 2020 values on the trend line as a number in red
ax.text(1920, temp_1920, f'{temp_1920:.2f}', color='red', fontsize=10, ha='right')
ax.text(2020, temp_2020, f'{temp_2020:.2f}', color='red', fontsize=10, ha='right')

# Display the plot without extra text
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# Slope of the trend line: nan °C/year
# posx and posy should be finite values
# posx and posy should be finite values

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np

# Filter the data between 1920 and 2020
bco_ann_climate_df_filtered = bco_ann_climate_df[(bco_ann_climate_df['Year'] >= 1920) & (bco_ann_climate_df['Year'] <= 2020)]

# Plot annual average temperature data with a red trend line for the filtered data
ax = sns.regplot(
    x=bco_ann_climate_df_filtered['Year'], 
    y=bco_ann_climate_df_filtered['TOBS_C'],
    line_kws={'color': 'red'},  # Change the trend line to red
)

# Set plot labels
ax.set(
    title='Boulder Colorado Observed Temperature Trend (1920-2020)',
    xlabel='YEAR',
    ylabel='Temperature ($^\circ$C)'  # Updated unit to Celsius
)

# Fit the OLS model to get the slope for the filtered data
X = sm.add_constant(bco_ann_climate_df_filtered['Year'])  # Add constant for the intercept
model = sm.OLS(bco_ann_climate_df_filtered['TOBS_C'], X).fit()  # Fit the model

# Extract the slope and intercept
slope = model.params['Year']
intercept = model.params['const']
print(f"Slope of the trend line (1920-2020): {slope:.4f} °C/year")

# Predict temperatures at 1920 and 2020
years = np.array([1920, 2020])
predicted_temps = intercept + slope * years

# Ensure values are finite to avoid plotting issues
predicted_temps = np.where(np.isfinite(predicted_temps), predicted_temps, np.nan)

# Annotate the predicted values on the plot
for year, temp in zip(years, predicted_temps):
    ax.text(year, temp, f'{temp:.2f}', color='red', fontsize=10, ha='center', va='bottom')

# Display the plot without extra text
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# Slope of the trend line (1920-2020): nan °C/year
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# To save the visualized data using hvplot as an HTML file named BCOCLIMATETREND.html, you'll need to replace the Seaborn and Matplotlib plotting with hvplot, a high-level plotting API built on top of HoloViews, which supports interactive plotting and exporting to HTML.
#
# Here's the modified code that uses hvplot to create an interactive plot and save it as an HTML file:
#
# this does not give me the trend line

# %%
import pandas as pd
import hvplot.pandas  # Import hvplot for pandas integration
import statsmodels.api as sm
import numpy as np

# Filter the data between 1920 and 2020
bco_ann_climate_df_filtered = bco_ann_climate_df[
    (bco_ann_climate_df['Year'] >= 1920) & (bco_ann_climate_df['Year'] <= 2020)
]

# Fit the OLS model to get the slope for the filtered data
X = sm.add_constant(bco_ann_climate_df_filtered['Year'])  # Add constant for the intercept
model = sm.OLS(bco_ann_climate_df_filtered['TOBS_C'], X).fit()  # Fit the model

# Extract the slope and intercept
slope = model.params['Year']
intercept = model.params['const']
print(f"Slope of the trend line (1920-2020): {slope:.4f} °C/year")

# Predict temperatures at 1920 and 2020
years = np.array([1920, 2020])
predicted_temps = intercept + slope * years

# Create a DataFrame for trend line predictions
trend_df = pd.DataFrame({
    'Year': years,
    'Predicted_Temperature': predicted_temps
})

# Create the plot using hvplot with a trend line
plot = bco_ann_climate_df_filtered.hvplot.scatter(
    x='Year', 
    y='TOBS_C', 
    color='blue', 
    title='Boulder Colorado Observed Temperature Trend (1920-2020)',
    xlabel='YEAR',
    ylabel='Temperature (°C)'
) * trend_df.hvplot.line(
    x='Year', 
    y='Predicted_Temperature', 
    color='red', 
    line_width=2, 
    label='Trend Line'
)

# Export the plot to an HTML file
hvplot.save(plot, 'BCOCLIMATETREND.html')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Slope of the trend line (1920-2020): nan °C/year
# /opt/conda/lib/python3.10/site-packages/holoviews/core/data/pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# ...

# %% [markdown]
# given the following code, add a grid at each .1 degree c as dots and each 1 degree c as lines on the plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np

# Filter the data between 1920 and 2020
bco_ann_climate_df_filtered = bco_ann_climate_df[
    (bco_ann_climate_df['Year'] >= 1920) & (bco_ann_climate_df['Year'] <= 2020)
]

# Plot annual average temperature data with a red trend line for the filtered data
ax = sns.regplot(
    x=bco_ann_climate_df_filtered['Year'], 
    y=bco_ann_climate_df_filtered['TOBS_C'],
    line_kws={'color': 'red'},  # Change the trend line to red
)

# Set plot labels
ax.set(
    title='Boulder Colorado Observed Temperature Trend (1920-2020)',
    xlabel='YEAR',
    ylabel='Temperature ($^\circ$C)'  # Updated unit to Celsius
)

# Fit the OLS model to get the slope for the filtered data
X = sm.add_constant(bco_ann_climate_df_filtered['Year'])  # Add constant for the intercept
model = sm.OLS(bco_ann_climate_df_filtered['TOBS_C'], X).fit()  # Fit the model

# Extract the slope and intercept
slope = model.params['Year']
intercept = model.params['const']
print(f"Slope of the trend line (1920-2020): {slope:.4f} °C/year")

# Predict temperatures at 1920 and 2020
years = np.array([1920, 2020])
predicted_temps = intercept + slope * years

# Ensure values are finite to avoid plotting issues
predicted_temps = np.where(np.isfinite(predicted_temps), predicted_temps, np.nan)

# Annotate the predicted values on the plot
for year, temp in zip(years, predicted_temps):
    ax.text(year, temp, f'{temp:.2f}', color='red', fontsize=10, ha='center', va='bottom')

# Add grid lines at 0.1°C intervals (dotted lines) and 1°C intervals (solid lines)
ax.xaxis.grid(True, which='major', color='gray', linestyle='-', linewidth=0.5)  # Major vertical grid (year)
ax.yaxis.grid(True, which='major', color='gray', linestyle='-', linewidth=0.5)  # Major horizontal grid (1°C)
ax.yaxis.grid(True, which='minor', color='gray', linestyle=':', linewidth=0.5)  # Minor horizontal grid (0.1°C)

# Set grid interval for the Y axis (temperature)
ax.set_yticks(np.arange(
    bco_ann_climate_df_filtered['TOBS_C'].min(), 
    bco_ann_climate_df_filtered['TOBS_C'].max() + 1, 1
))
ax.set_yticks(np.arange(
    bco_ann_climate_df_filtered['TOBS_C'].min(), 
    bco_ann_climate_df_filtered['TOBS_C'].max() + 0.1, 0.1
), minor=True)

# Display the plot
plt.show()
# Out:
# Slope of the trend line (1920-2020): nan °C/year
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# given the following code, add a grid at each .1 degree c as dots and each 1 degree c as lines on the plot another alternative

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np

# Filter the data between 1920 and 2020
bco_ann_climate_df_filtered = bco_ann_climate_df[
    (bco_ann_climate_df['Year'] >= 1920) & (bco_ann_climate_df['Year'] <= 2020)
]

# Plot annual average temperature data with a red trend line for the filtered data
ax = sns.regplot(
    x=bco_ann_climate_df_filtered['Year'],
    y=bco_ann_climate_df_filtered['TOBS_C'],
    line_kws={'color': 'red'},  # Change the trend line to red
)

# Set plot labels
ax.set(
    title='Boulder Colorado Observed Temperature Trend (1920-2020)',
    xlabel='YEAR',
    ylabel='Temperature ($^\circ$C)'  # Updated unit to Celsius
)

# Fit the OLS model to get the slope for the filtered data
X = sm.add_constant(bco_ann_climate_df_filtered['Year'])  # Add constant for the intercept
model = sm.OLS(bco_ann_climate_df_filtered['TOBS_C'], X).fit()  # Fit the model

# Extract the slope and intercept
slope = model.params['Year']
intercept = model.params['const']
print(f"Slope of the trend line (1920-2020): {slope:.4f} °C/year")

# Predict temperatures at 1920 and 2020
years = np.array([1920, 2020])
predicted_temps = intercept + slope * years

# Ensure values are finite to avoid plotting issues
predicted_temps = np.where(np.isfinite(predicted_temps), predicted_temps, np.nan)

# Annotate the predicted values on the plot
for year, temp in zip(years, predicted_temps):
    ax.text(year, temp, f'{temp:.2f}', color='red', fontsize=10, ha='center', va='bottom')

# Set grid with lines at 1 degree intervals and dots at 0.1 degree intervals
ax.grid(which='major', color='gray', linestyle='-', linewidth=0.75)  # Major grid lines at 1 degree intervals
ax.grid(which='minor', color='gray', linestyle=':', linewidth=0.5)  # Minor grid dots at 0.1 degree intervals

# Enable minor ticks for the minor grid lines and dots
ax.minorticks_on()

# Display the plot without extra text
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# Slope of the trend line (1920-2020): nan °C/year
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# The slope of the line (simplify by using a 100 year period)
# 1920 11.75
# 2020 13
# 𝑚 =
# 𝑦2 − 𝑦1
# 𝑥2 − 𝑥1
# Step 1
# Assign the values to the variables.
# 𝑥1 = 1920
# 𝑦1 = 11.75
# 𝑥2 = 2020
# 𝑦2 = 13
# Step 2
# Substitute the values into the slope formula.
# 𝑚 =
# 𝑦2 − 𝑦1
# 𝑥2 − 𝑥1
# 𝑚 =
# 13 − 11.75
# 2020 − 1920
# Step 3
# Simplify the expression.
# 0.0125

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd

# Assuming bco_ann_climate_df is defined and loaded correctly with 'Year' and 'TOBS_C' columns
# Filter the data between 1920 and 2020 - I did this to make eyeball calculation easy as I got .0125 as slope
# update to use the first year that there is temperature data which is 1/1901 through the end of the data throuh 9/2023
bco_ann_climate_df_filtered = bco_ann_climate_df[
    (bco_ann_climate_df['Year'] >= 1901) & (bco_ann_climate_df['Year'] <= 2023)
]

# Remove rows with missing or infinite values to avoid NaN slope
bco_ann_climate_df_filtered = bco_ann_climate_df_filtered.replace([np.inf, -np.inf], np.nan).dropna()

# Plot annual average temperature data with a red trend line for the filtered data
ax = sns.regplot(
    x=bco_ann_climate_df_filtered['Year'],
    y=bco_ann_climate_df_filtered['TOBS_C'],
    line_kws={'color': 'red'},  # Change the trend line to red
)

# Set plot labels
ax.set(
    title='Boulder Colorado Observed Temperature Trend (1901-2023)',
    xlabel='YEAR',
    ylabel='Temperature ($^\circ$C)'  # Updated unit to Celsius
)

# Prepare data for scikit-learn Linear Regression
X = bco_ann_climate_df_filtered[['Year']].values  # 2D array for scikit-learn
y = bco_ann_climate_df_filtered['TOBS_C'].values

# Fit the Linear Regression model
model = LinearRegression()
model.fit(X, y)

# Extract the slope and intercept
slope = model.coef_[0]
intercept = model.intercept_
print(f"Slope: {slope:.4f} °C/year")
print(f"Intercept: {intercept:.4f} °C")

# Annotate the predicted values on the plot for 1901 and 2022 last full year of data
years = np.array([1901, 2022]).reshape(-1, 1)
predicted_temps = model.predict(years)

for year, temp in zip(years.flatten(), predicted_temps):
    ax.text(year, temp, f'{temp:.2f}', color='red', fontsize=24, ha='center', va='bottom')
    

# Display the plot without extra text
plt.grid(which='both', linestyle=':', linewidth=0.5)
plt.show()
# Out:
# Slope: 0.0181 °C/year
# Intercept: -22.9880 °C

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: Interpret the trend</div></div><div class="callout-body-container callout-body"><ol type="1">
# <li><p>Create a new Markdown cell below this one.</p></li>
# <li><p>Write a plot headline. Your headline should
# <strong>interpret</strong> your plot, unlike a caption which neutrally
# describes the image.</p></li>
# <li><p>Is the climate changing? How much? Report the slope of your trend
# line.</p></li>
# </ol></div></div>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
import pandas as pd

# Assuming bco_ann_climate_df is defined and loaded correctly with 'Year' and 'TOBS_C' columns
# Filter the data between 1901 and 2023
bco_ann_climate_df_filtered = bco_ann_climate_df[
    (bco_ann_climate_df['Year'] >= 1901) & (bco_ann_climate_df['Year'] <= 2023)
]

# Remove rows with missing or infinite values to avoid NaN slope
bco_ann_climate_df_filtered = bco_ann_climate_df_filtered.replace([np.inf, -np.inf], np.nan).dropna()

# Plot annual average temperature data with a red trend line for the filtered data
ax = sns.regplot(
    x=bco_ann_climate_df_filtered['Year'],
    y=bco_ann_climate_df_filtered['TOBS_C'],
    line_kws={'color': 'red'},  # Change the trend line to red
)

# Set plot labels
ax.set(
    title='Boulder Colorado Observed Temperature Trend (1901-2023)',
    xlabel='YEAR',
    ylabel='Temperature ($^\circ$C)'  # Updated unit to Celsius
)

# Prepare data for statsmodels OLS Regression
X = bco_ann_climate_df_filtered[['Year']]  # Predictor variable (Year)
y = bco_ann_climate_df_filtered['TOBS_C']  # Response variable (Temperature)

# Add a constant (intercept term) to the predictor
X = sm.add_constant(X)

# Fit the OLS model
model = sm.OLS(y, X).fit()

# Print the OLS model summary
print(model.summary())

# Extract the slope and intercept
slope = model.params['Year']
intercept = model.params['const']
print(f"Slope: {slope:.4f} °C/year")
print(f"Intercept: {intercept:.4f} °C")

# Annotate the predicted values on the plot for 1901 and 2022 (last full year of data)
years = np.array([1901, 2022])
predicted_temps = intercept + slope * years

for year, temp in zip(years, predicted_temps):
    ax.text(year, temp, f'{temp:.2f}', color='red', fontsize=24, ha='center', va='bottom')

# Display the plot without extra text
plt.grid(which='both', linestyle=':', linewidth=0.5)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 TOBS_C   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.076
# Method:                 Least Squares   F-statistic:                     10.83
# Date:                Tue, 24 Sep 2024   Prob (F-statistic):            0.00132
# Time:                        20:14:32   Log-Likelihood:                -261.33
# No. Observations:                 120   AIC:                             526.7
# Df Residuals:                     118   BIC:                             532.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -22.9880     10.793     -2.130      0.035     -44.362      -1.614
# ...

# %% [markdown]
# ### Increasing annual average temperature trend in Boulder Colorado
# #### Given most daily data from Boulder Colorado Station USC0005048 of NOAA Global Historical Climatology Network between January 1901 and September 2023, there is an average increase of +0.0181 °C per year based upon calculation of average mean temperature using a linear ordinary least squares analysis of the temperature trend (shown in red on the chart).  Mean temperature was 11.41°C in 1901 and 13.60 in 2022 (last full year of data in set)

# %% [markdown]
# > ** Your task:**
# >
# > 1.  Research the [**Global Historical Climatology Network -
# >     Daily**](https://www.ncei.noaa.gov/metadata/geoportal/rest/metadata/item/gov.noaa.ncdc:C00861/html)
# >     data source.
# > 2.  In the cell below, write a 2-3 sentence description of the data
# >     source.
# > 3.  Include a citation of the data (**HINT:** See the ‘Data Citation’
# >     tab on the GHCNd overview page).
# >
# > Your description should include:
# >
# > -   who takes the data
# > -   where the data were taken
# > -   what the maximum temperature units are
# > -   how the data are collected

# %% [markdown]
# Data source is U.S. Department of Commerce National Centers for Environmental Information
# National Oceanic & Atmospheric Administration
# National Environmental Satellite, Data, and Information Service
# 151 Patton Avenue, Asheville, North Carolina 28801
# These data are quality controlled and may not be identical to the original observations.
#
# The data is from the same general area with some minor precise latitude/longitude and elevation variations during the observation timeframe of 1893-date https://www.ncdc.noaa.gov/cdo-web/datasets/GHCND/stations/GHCND:USC00050848/detail.  Current Location: Elev: 5489 ft. Lat: 39.9928° N Lon: 105.2668° W
#
# The maximum temperature units are in degrees fahrenheit
#
# The current collection is via Max-Min Thermometers daily at	1700
# The history of collection techniques are at https://www.ncdc.noaa.gov/cdo-web/datasets/GHCND/stations/GHCND:USC00050848/detail
#
# The Global Historical Climatology Network - Daily (GHCN-Daily/GHCNd) dataset integrates daily climate observations from approximately 30 different data sources. Version 3 was released in September 2012 with the addition of data from two additional station networks. Changes to the processing system associated with the version 3 release also allowed for updates to occur 7 days a week rather than only on most weekdays. Version 3 contains station-based measurements from well over 90,000 land-based stations worldwide, about two thirds of which are for precipitation measurement only. Other meteorological elements include, but are not limited to, daily maximum and minimum temperature, temperature at the time of observation, snowfall and snow depth. Over 25,000 stations are regularly updated with observations from within roughly the last month. The dataset is also routinely reconstructed (usually every week) from its roughly 30 data sources to ensure that GHCNd is generally in sync with its growing list of constituent sources. During this process, quality assurance checks are applied to the full dataset. Where possible, GHCNd station data are also updated daily from a variety of data streams. Station values for each daily update also undergo a suite of quality checks.
#
# Citation: Menne, Matthew J., Imke Durre, Bryant Korzeniewski, Shelley McNeill, Kristy Thomas, Xungang Yin, Steven Anthony, Ron Ray, Russell S. Vose, Byron E.Gleason, and Tamara G. Houston (2012): Global Historical Climatology Network - Daily (GHCN-Daily), Version 3. [indicate subset used]. NOAA National Climatic Data Center. doi:10.7289/V5D21VHZ [2024-09-24].🛎️
